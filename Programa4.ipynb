# %% [markdown]
# <a href="https://colab.research.google.com/github/Brayan56-mdz/Programacion_avanzada_2/blob/main/Programa4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Generador de CURP ")
no=str(input("Ingresa tu nombre: "))
ap=str(input("Ingresa tu apellido paterno: "))
am=str(input("Ingresa tu apellido materno:  "))
an=str(input("Ingresa tu año: "))
if len(an) > 5:
    print("Numero invalido, vuelve a intentarlo")
    an=str(input("Ingresa tu año de nacimiento: "))

mes=str(input("Ingresa el numero de tu mes de nacimiento: "))
dia=str(input("Ingresa el dia: "))
gen=str(input("Ingrese su genero: "))
hes=str(input("Ingrese su entidad federativa : "))

#identificar primera vocal del apellido
def filtrar(i):
    if i != -1:
        return i
    return 45000
palabra=ap
palabra = palabra.lower()
a = filtrar(palabra.find("a"))
e = filtrar(palabra.find("e"))
i = filtrar(palabra.find("i"))
o = filtrar(palabra.find("o"))
u = filtrar(palabra.find("u"))
#vocal = min(a, min(e, min(i, min(o, u)))) => forma larga
vocal = min([a, e, i, o, u])

#penultimo numero del año de nacimiento
startLoc = 2
endLoc = 3
penul = an[startLoc: endLoc]

#ultimo numero del año de nacimiento
startLoc = 3
endLoc = 4
ult = an[startLoc: endLoc]

#primer numero del mes de nacimiento
startLoc = 0
endLoc = 1
pri = mes[startLoc: endLoc]

#segundo numero del mes de nacimiento
startLoc = 1
endLoc = 2
seg = mes[startLoc: endLoc]

#primer numero del dia de nacimiento
startLoc = 0
endLoc = 1
num1 = dia[startLoc: endLoc]

#segundo numero del dia de nacimiento
startLoc = 1
endLoc = 2
num2 = dia[startLoc: endLoc]

#genero 
startLoc = 0
endLoc = 1
gen1 = gen[startLoc: endLoc]

#entidad federativa 
cadena=hes
palabras = cadena.split()
ent= "".join([palabra[0] for palabra in cadena.split()])

#primer consonante del apellido paterno
def filtrar(i):
    if i != -1:
        return i
    return 45000

startLoc = 2
endLoc = 20
con1 = ap[startLoc: endLoc]

consonante=con1
consonante = consonante.lower()
b = filtrar(consonante.find("b"))
c = filtrar(consonante.find("c"))
d = filtrar(consonante.find("d"))
f = filtrar(consonante.find("f"))
g = filtrar(consonante.find("g"))
h = filtrar(consonante.find("h"))
j = filtrar(consonante.find("j"))
k = filtrar(consonante.find("k"))
l = filtrar(consonante.find("l"))
m = filtrar(consonante.find("m"))
n = filtrar(consonante.find("n"))
p = filtrar(consonante.find("p"))
q = filtrar(consonante.find("q"))
r = filtrar(consonante.find("r"))
s = filtrar(consonante.find("s"))
t = filtrar(consonante.find("t"))
v = filtrar(consonante.find("v"))
w = filtrar(consonante.find("w"))
x = filtrar(consonante.find("x"))
y = filtrar(consonante.find("y"))
z = filtrar(consonante.find("z"))

conso = min([b, c, d, f, g, h, j, k, l, m, n, p, q, r, s, t, v, w, x, y, z])
conap=str(consonante[conso])

#primera consonante del apellido materno
def filtrar(i):
    if i != -1:
        return i
    return 45000

startLoc = 2
endLoc = 20
con2 = am[startLoc: endLoc]

consonante=con2
consonante = consonante.lower()
b = filtrar(consonante.find("b"))
c = filtrar(consonante.find("c"))
d = filtrar(consonante.find("d"))
f = filtrar(consonante.find("f"))
g = filtrar(consonante.find("g"))
h = filtrar(consonante.find("h"))
j = filtrar(consonante.find("j"))
k = filtrar(consonante.find("k"))
l = filtrar(consonante.find("l"))
m = filtrar(consonante.find("m"))
n = filtrar(consonante.find("n"))
p = filtrar(consonante.find("p"))
q = filtrar(consonante.find("q"))
r = filtrar(consonante.find("r"))
s = filtrar(consonante.find("s"))
t = filtrar(consonante.find("t"))
v = filtrar(consonante.find("v"))
w = filtrar(consonante.find("w"))
x = filtrar(consonante.find("x"))
y = filtrar(consonante.find("y"))
z = filtrar(consonante.find("z"))

conso = min([b, c, d, f, g, h, j, k, l, m, n, p, q, r, s, t, v, w, x, y, z])

conam=str(consonante[conso])

#
def filtrar(i):
    if i != -1:
        return i
    return 45000

startLoc = 1
endLoc = 20
con3 = no[startLoc: endLoc]

consonante=con3
consonante = consonante.lower()
b = filtrar(consonante.find("b"))
c = filtrar(consonante.find("c"))
d = filtrar(consonante.find("d"))
f = filtrar(consonante.find("f"))
g = filtrar(consonante.find("g"))
h = filtrar(consonante.find("h"))
j = filtrar(consonante.find("j"))
k = filtrar(consonante.find("k"))
l = filtrar(consonante.find("l"))
m = filtrar(consonante.find("m"))
n = filtrar(consonante.find("n"))
p = filtrar(consonante.find("p"))
q = filtrar(consonante.find("q"))
r = filtrar(consonante.find("r"))
s = filtrar(consonante.find("s"))
t = filtrar(consonante.find("t"))
v = filtrar(consonante.find("v"))
w = filtrar(consonante.find("w"))
x = filtrar(consonante.find("x"))
y = filtrar(consonante.find("y"))
z = filtrar(consonante.find("z"))

conso = min([b, c, d, f, g, h, j, k, l, m, n, p, q, r, s, t, v, w, x, y, z])

conan=str(consonante[conso])

print("Tu CURP es: ",ap[0:1],palabra[vocal],am[0:1],no[0:1],penul,ult,pri,seg,num1,num2,gen1,ent,conap,conam,conan)
